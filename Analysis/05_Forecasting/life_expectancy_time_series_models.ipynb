# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from IPython.display import display
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.tsa.holtwinters import ExponentialSmoothing

warnings.filterwarnings("ignore")

sns.set_theme(style="whitegrid")
plt.rcParams["figure.figsize"] = (12, 6)

LIFE_PATH = "/Users/tonytony/Final Project/Data/Raw/life_expectancy.csv"
META_PATH = "/Users/tonytony/Final Project/Data/Raw/world_bank_country_metadata.csv"

WINDOW_SIZE = 10

print("Libraries imported successfully")
print("Life Expectancy path:", LIFE_PATH)
print("Metadata path:", META_PATH)
print("Rolling window size:", WINDOW_SIZE)
# Out:
# Libraries imported successfully
# Life Expectancy path: /Users/tonytony/Final Project/Data/Raw/life_expectancy.csv
# Metadata path: /Users/tonytony/Final Project/Data/Raw/world_bank_country_metadata.csv
# Rolling window size: 10

# %%
meta_df = pd.read_csv(META_PATH)

region_map = meta_df[[
    "Country Code",
    "World Bank Region"
]].copy().rename(columns={
    "Country Code": "country_code",
    "World Bank Region": "wb_region"
})

region_map["country_type"] = np.where(
    region_map["wb_region"].astype(str).str.strip().eq("Aggregates"),
    "Aggregate",
    "Country/Territory"
)

def load_wdi(path):
    df = pd.read_csv(path, skiprows=4)
    df = df.drop(
        columns=[col for col in df.columns if str(col).startswith("Unnamed")],
        errors="ignore"
    )
    year_cols = [col for col in df.columns if str(col).isdigit()]
    df[year_cols] = df[year_cols].apply(pd.to_numeric, errors="coerce")
    return df

def to_long(df, value_name):
    long_df = df.melt(
        id_vars=["Country Name", "Country Code", "Indicator Name", "Indicator Code"],
        value_vars=[col for col in df.columns if str(col).isdigit()],
        var_name="year",
        value_name=value_name
    ).rename(columns={
        "Country Name": "country_name",
        "Country Code": "country_code",
        "Indicator Name": "indicator_name",
        "Indicator Code": "indicator_code"
    })

    long_df["year"] = pd.to_numeric(long_df["year"], errors="coerce").astype("int64")
    long_df[value_name] = pd.to_numeric(long_df[value_name], errors="coerce")
    return long_df

def add_region_info(long_df):
    merged = long_df.merge(region_map, on="country_code", how="left")
    merged = merged[merged["country_type"] == "Country/Territory"].copy()
    return merged

def forecast_metrics(y_true, y_pred):
    y_true = np.asarray(y_true, dtype=float)
    y_pred = np.asarray(y_pred, dtype=float)

    mae = np.mean(np.abs(y_true - y_pred))
    rmse = np.sqrt(np.mean((y_true - y_pred) ** 2))

    non_zero_mask = y_true != 0
    if non_zero_mask.sum() > 0:
        mape = np.mean(np.abs((y_true[non_zero_mask] - y_pred[non_zero_mask]) / y_true[non_zero_mask])) * 100
    else:
        mape = np.nan

    ss_res = np.sum((y_true - y_pred) ** 2)
    ss_tot = np.sum((y_true - np.mean(y_true)) ** 2)
    r2 = 1 - ss_res / ss_tot if ss_tot != 0 else np.nan

    return {
        "MAE": mae,
        "RMSE": rmse,
        "MAPE_pct": mape,
        "R_squared": r2
    }
    
def format_life_output(df):
    format_map = {}

    for col in ["actual", "predicted", "predicted_life_expectancy", "actual_life_expectancy"]:
        if col in df.columns:
            format_map[col] = "{:,.2f}"

    for col in ["MAE", "RMSE", "MAPE_pct", "R_squared"]:
        if col in df.columns:
            format_map[col] = "{:,.4f}"

    return df.style.format(format_map)

print("Helper functions are ready")
region_map.head()
# Out:
# Helper functions are ready
#   country_code                                          wb_region  \
# 0          ABW                         Latin America & Caribbean
# 1          AFE                                         Aggregates
# 2          AFG  Middle East, North Africa, Afghanistan & Pakistan
# 3          AFR                                         Aggregates
# 4          AFW                                         Aggregates
#
#         country_type
# 0  Country/Territory
# 1          Aggregate
# 2  Country/Territory
# 3          Aggregate
# 4          Aggregate

# %%
life_raw = load_wdi(LIFE_PATH)
life_long = add_region_info(to_long(life_raw, "life_expectancy_years"))

life_long = life_long[
    life_long["life_expectancy_years"].notna()
].copy()

print("Life Expectancy long shape:", life_long.shape)
print("Countries:", life_long["country_code"].nunique())
print("Year range:", int(life_long["year"].min()), "-", int(life_long["year"].max()))

life_long.head()
# Out:
# Life Expectancy long shape: (13854, 8)
# Countries: 217
# Year range: 1960 - 2023
#   country_name country_code                           indicator_name  \
# 0        Aruba          ABW  Life expectancy at birth, total (years)
# 2  Afghanistan          AFG  Life expectancy at birth, total (years)
# 4       Angola          AGO  Life expectancy at birth, total (years)
# 5      Albania          ALB  Life expectancy at birth, total (years)
# 6      Andorra          AND  Life expectancy at birth, total (years)
#
#    indicator_code  year  life_expectancy_years  \
# 0  SP.DYN.LE00.IN  1960                 64.049
# 2  SP.DYN.LE00.IN  1960                 32.799
# 4  SP.DYN.LE00.IN  1960                 37.933
# 5  SP.DYN.LE00.IN  1960                 56.413
# 6  SP.DYN.LE00.IN  1960                 72.094
#
#                                            wb_region       country_type
# 0                         Latin America & Caribbean   Country/Territory
# 2  Middle East, North Africa, Afghanistan & Pakistan  Country/Territory
# 4                                Sub-Saharan Africa   Country/Territory
# 5                              Europe & Central Asia  Country/Territory
# 6                              Europe & Central Asia  Country/Territory

# %%
life_model_plan = pd.DataFrame({
    "Dataset": ["Life Expectancy", "Life Expectancy", "Life Expectancy"],
    "Candidate Model": ["Naive", "AutoReg", "Holt"],
    "Description": [
        "Uses the previous year's life expectancy as the forecast.",
        "Uses autoregressive dependence on previous life expectancy values.",
        "Uses Holt linear trend for smooth trend-based forecasting."
    ]
})

life_model_plan
# Out:
#            Dataset Candidate Model  \
# 0  Life Expectancy           Naive
# 1  Life Expectancy         AutoReg
# 2  Life Expectancy            Holt
#
#                                          Description
# 0  Uses the previous year's life expectancy as th...
# 1  Uses autoregressive dependence on previous lif...
# 2  Uses Holt linear trend for smooth trend-based ...

# %%
def one_step_life_forecast(window_values, model_name, autoreg_lags=3):
    series = pd.Series(window_values, dtype=float)

    if model_name == "Naive":
        return float(series.iloc[-1])

    if model_name == "AutoReg":
        lags = min(autoreg_lags, len(series) - 2)
        if lags < 1:
            return float(series.iloc[-1])

        fit = AutoReg(series, lags=lags, old_names=False, trend="c").fit()
        pred = fit.predict(start=len(series), end=len(series)).iloc[0]
        return float(pred)

    if model_name == "Holt":
        fit = ExponentialSmoothing(
            series,
            trend="add",
            seasonal=None,
            damped_trend=False
        ).fit()
        pred = fit.forecast(1).iloc[0]
        return float(pred)

    raise ValueError(f"Unknown model: {model_name}")

def rolling_life_backtest(
    long_df,
    value_col="life_expectancy_years",
    candidate_models=None,
    window_size=10,
    min_total_obs=15
):
    if candidate_models is None:
        candidate_models = ["Naive", "AutoReg", "Holt"]

    prediction_rows = []
    skipped_rows = []

    grouped = long_df[["country_name", "country_code", "wb_region", "year", value_col]].dropna().groupby("country_code")

    for country_code, group in grouped:
        group = group.sort_values("year").copy()

        if len(group) < max(min_total_obs, window_size + 1):
            skipped_rows.append({
                "country_code": country_code,
                "country_name": group["country_name"].iloc[0],
                "reason": "too_few_observations"
            })
            continue

        values = group[value_col].values.astype(float)
        years = group["year"].values.astype(int)
        country_name = group["country_name"].iloc[0]
        wb_region = group["wb_region"].iloc[0]

        for i in range(window_size, len(group)):
            train_window = values[i - window_size:i]
            actual_value = values[i]
            actual_year = int(years[i])

            for model_name in candidate_models:
                try:
                    predicted_value = one_step_life_forecast(
                        window_values=train_window,
                        model_name=model_name
                    )

                    prediction_rows.append({
                        "Dataset": "Life Expectancy",
                        "Model": model_name,
                        "country_code": country_code,
                        "country_name": country_name,
                        "wb_region": wb_region,
                        "year": actual_year,
                        "actual": actual_value,
                        "predicted": predicted_value
                    })

                except Exception as e:
                    skipped_rows.append({
                        "country_code": country_code,
                        "country_name": country_name,
                        "reason": f"{model_name} failed at year {actual_year}: {str(e)}"
                    })

    pred_df = pd.DataFrame(prediction_rows)
    skipped_df = pd.DataFrame(skipped_rows)

    summary_rows = []
    if not pred_df.empty:
        for model_name, temp in pred_df.groupby("Model"):
            metrics = forecast_metrics(temp["actual"], temp["predicted"])
            summary_rows.append({
                "Dataset": "Life Expectancy",
                "Model": model_name,
                **metrics,
                "n_predictions": len(temp),
                "n_countries_modeled": temp["country_code"].nunique()
            })

    summary_df = pd.DataFrame(summary_rows)
    return pred_df, summary_df, skipped_df

print("Life Expectancy backtest engine is ready")
# Out:
# Life Expectancy backtest engine is ready

# %%
life_predictions, life_summary, life_skipped = rolling_life_backtest(
    long_df=life_long,
    value_col="life_expectancy_years",
    candidate_models=["Naive", "AutoReg", "Holt"],
    window_size=WINDOW_SIZE,
    min_total_obs=15
)

print("Life Expectancy candidate model results")
display(life_summary.round(4))

print("Skipped rows:", life_skipped.shape[0])
display(format_life_output(life_predictions.head(15)))
# Out:
# Life Expectancy candidate model results
#            Dataset    Model     MAE      RMSE  MAPE_pct  R_squared  \
# 0  Life Expectancy  AutoReg  9.0079  461.0532   21.9902 -1918.1162
# 1  Life Expectancy     Holt  0.5449    1.7460    1.0385     0.9725
# 2  Life Expectancy    Naive  0.5428    1.4984    0.9950     0.9797
#
#    n_predictions  n_countries_modeled
# 0          11684                  217
# 1          11684                  217
# 2          11684                  217
# Skipped rows: 0
# <style type="text/css">
# </style>
# <table id="T_b34d7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b34d7_level0_col0" class="col_heading level0 col0" >Dataset</th>
#       <th id="T_b34d7_level0_col1" class="col_heading level0 col1" >Model</th>
#       <th id="T_b34d7_level0_col2" class="col_heading level0 col2" >country_code</th>
#       <th id="T_b34d7_level0_col3" class="col_heading level0 col3" >country_name</th>
#       <th id="T_b34d7_level0_col4" class="col_heading level0 col4" >wb_region</th>
#       <th id="T_b34d7_level0_col5" class="col_heading level0 col5" >year</th>
#       <th id="T_b34d7_level0_col6" class="col_heading level0 col6" >actual</th>
#       <th id="T_b34d7_level0_col7" class="col_heading level0 col7" >predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b34d7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b34d7_row0_col0" class="data row0 col0" >Life Expectancy</td>
#       <td id="T_b34d7_row0_col1" class="data row0 col1" >Naive</td>
#       <td id="T_b34d7_row0_col2" class="data row0 col2" >ABW</td>
#       <td id="T_b34d7_row0_col3" class="data row0 col3" >Aruba</td>
#       <td id="T_b34d7_row0_col4" class="data row0 col4" >Latin America & Caribbean </td>
#       <td id="T_b34d7_row0_col5" class="data row0 col5" >1970</td>
#       <td id="T_b34d7_row0_col6" class="data row0 col6" >67.44</td>
#       <td id="T_b34d7_row0_col7" class="data row0 col7" >67.10</td>
#     </tr>
#     <tr>
#       <th id="T_b34d7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b34d7_row1_col0" class="data row1 col0" >Life Expectancy</td>
#       <td id="T_b34d7_row1_col1" class="data row1 col1" >AutoReg</td>
#       <td id="T_b34d7_row1_col2" class="data row1 col2" >ABW</td>
#       <td id="T_b34d7_row1_col3" class="data row1 col3" >Aruba</td>
#       <td id="T_b34d7_row1_col4" class="data row1 col4" >Latin America & Caribbean </td>
#       <td id="T_b34d7_row1_col5" class="data row1 col5" >1970</td>
#       <td id="T_b34d7_row1_col6" class="data row1 col6" >67.44</td>
#       <td id="T_b34d7_row1_col7" class="data row1 col7" >67.45</td>
#     </tr>
#     <tr>
#       <th id="T_b34d7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b34d7_row2_col0" class="data row2 col0" >Life Expectancy</td>
#       <td id="T_b34d7_row2_col1" class="data row2 col1" >Holt</td>
#       <td id="T_b34d7_row2_col2" class="data row2 col2" >ABW</td>
#       <td id="T_b34d7_row2_col3" class="data row2 col3" >Aruba</td>
#       <td id="T_b34d7_row2_col4" class="data row2 col4" >Latin America & Caribbean </td>
#       <td id="T_b34d7_row2_col5" class="data row2 col5" >1970</td>
#       <td id="T_b34d7_row2_col6" class="data row2 col6" >67.44</td>
#       <td id="T_b34d7_row2_col7" class="data row2 col7" >67.44</td>
#     </tr>
#     <tr>
#       <th id="T_b34d7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b34d7_row3_col0" class="data row3 col0" >Life Expectancy</td>
#       <td id="T_b34d7_row3_col1" class="data row3 col1" >Naive</td>
#       <td id="T_b34d7_row3_col2" class="data row3 col2" >ABW</td>
#       <td id="T_b34d7_row3_col3" class="data row3 col3" >Aruba</td>
#       <td id="T_b34d7_row3_col4" class="data row3 col4" >Latin America & Caribbean </td>
#       <td id="T_b34d7_row3_col5" class="data row3 col5" >1971</td>
#       <td id="T_b34d7_row3_col6" class="data row3 col6" >67.78</td>
#       <td id="T_b34d7_row3_col7" class="data row3 col7" >67.44</td>
#     </tr>
#     <tr>
#       <th id="T_b34d7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b34d7_row4_col0" class="data row4 col0" >Life Expectancy</td>
#       <td id="T_b34d7_row4_col1" class="data row4 col1" >AutoReg</td>
#       <td id="T_b34d7_row4_col2" class="data row4 col2" >ABW</td>
#       <td id="T_b34d7_row4_col3" class="data row4 col3" >Aruba</td>
#       <td id="T_b34d7_row4_col4" class="data row4 col4" >Latin America & Caribbean </td>
#       <td id="T_b34d7_row4_col5" class="data row4 col5" >1971</td>
#       <td id="T_b34d7_row4_col6" class="data row4 col6" >67.78</td>
#       <td id="T_b34d7_row4_col7" class="data row4 col7" >67.79</td>
#     </tr>
#     <tr>
#       <th id="T_b34d7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b34d7_row5_col0" class="data row5 col0" >Life Expectancy</td>
#       <td id="T_b34d7_row5_col1" class="data row5 col1" >Holt</td>
#       <td id="T_b34d7_row5_col2" class="data row5 col2" >ABW</td>
#       <td id="T_b34d7_row5_col3" class="data row5 col3" >Aruba</td>
#       <td id="T_b34d7_row5_col4" class="data row5 col4" >Latin America & Caribbean </td>
#       <td id="T_b34d7_row5_col5" class="data row5 col5" >1971</td>
#       <td id="T_b34d7_row5_col6" class="data row5 col6" >67.78</td>
#       <td id="T_b34d7_row5_col7" class="data row5 col7" >67.82</td>
#     </tr>
#     <tr>
#       <th id="T_b34d7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b34d7_row6_col0" class="data row6 col0" >Life Expectancy</td>
#       <td id="T_b34d7_row6_col1" class="data row6 col1" >Naive</td>
#       <td id="T_b34d7_row6_col2" class="data row6 col2" >ABW</td>
#       <td id="T_b34d7_row6_col3" class="data row6 col3" >Aruba</td>
#       <td id="T_b34d7_row6_col4" class="data row6 col4" >Latin America & Caribbean </td>
#       <td id="T_b34d7_row6_col5" class="data row6 col5" >1972</td>
#       <td id="T_b34d7_row6_col6" class="data row6 col6" >68.33</td>
#       <td id="T_b34d7_row6_col7" class="data row6 col7" >67.78</td>
#     </tr>
#     <tr>
#       <th id="T_b34d7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b34d7_row7_col0" class="data row7 col0" >Life Expectancy</td>
#       <td id="T_b34d7_row7_col1" class="data row7 col1" >AutoReg</td>
#       <td id="T_b34d7_row7_col2" class="data row7 col2" >ABW</td>
#       <td id="T_b34d7_row7_col3" class="data row7 col3" >Aruba</td>
#       <td id="T_b34d7_row7_col4" class="data row7 col4" >Latin America & Caribbean </td>
#       <td id="T_b34d7_row7_col5" class="data row7 col5" >1972</td>
#       <td id="T_b34d7_row7_col6" class="data row7 col6" >68.33</td>
#       <td id="T_b34d7_row7_col7" class="data row7 col7" >68.12</td>
#     </tr>
#     <tr>
#       <th id="T_b34d7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b34d7_row8_col0" class="data row8 col0" >Life Expectancy</td>
#       <td id="T_b34d7_row8_col1" class="data row8 col1" >Holt</td>
#       <td id="T_b34d7_row8_col2" class="data row8 col2" >ABW</td>
#       <td id="T_b34d7_row8_col3" class="data row8 col3" >Aruba</td>
#       <td id="T_b34d7_row8_col4" class="data row8 col4" >Latin America & Caribbean </td>
#       <td id="T_b34d7_row8_col5" class="data row8 col5" >1972</td>
#       <td id="T_b34d7_row8_col6" class="data row8 col6" >68.33</td>
#       <td id="T_b34d7_row8_col7" class="data row8 col7" >68.16</td>
#     </tr>
#     <tr>
#       <th id="T_b34d7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b34d7_row9_col0" class="data row9 col0" >Life Expectancy</td>
#       <td id="T_b34d7_row9_col1" class="data row9 col1" >Naive</td>
#       <td id="T_b34d7_row9_col2" class="data row9 col2" >ABW</td>
#       <td id="T_b34d7_row9_col3" class="data row9 col3" >Aruba</td>
#       <td id="T_b34d7_row9_col4" class="data row9 col4" >Latin America & Caribbean </td>
#       <td id="T_b34d7_row9_col5" class="data row9 col5" >1973</td>
#       <td id="T_b34d7_row9_col6" class="data row9 col6" >68.86</td>
#       <td id="T_b34d7_row9_col7" class="data row9 col7" >68.33</td>
#     </tr>
#     <tr>
#       <th id="T_b34d7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b34d7_row10_col0" class="data row10 col0" >Life Expectancy</td>
#       <td id="T_b34d7_row10_col1" class="data row10 col1" >AutoReg</td>
#       <td id="T_b34d7_row10_col2" class="data row10 col2" >ABW</td>
#       <td id="T_b34d7_row10_col3" class="data row10 col3" >Aruba</td>
#       <td id="T_b34d7_row10_col4" class="data row10 col4" >Latin America & Caribbean </td>
#       <td id="T_b34d7_row10_col5" class="data row10 col5" >1973</

# %%
life_summary_sorted = life_summary.sort_values(["RMSE", "MAE", "MAPE_pct"]).reset_index(drop=True)
best_life_model = life_summary_sorted.head(1).copy()

print("Sorted Life Expectancy model results")
display(life_summary_sorted.round(4))

print("Best Life Expectancy model")
display(best_life_model.style.format({
    "MAE": "{:,.4f}",
    "RMSE": "{:,.4f}",
    "MAPE_pct": "{:,.4f}",
    "R_squared": "{:,.4f}"
}))
# Out:
# Sorted Life Expectancy model results
#            Dataset    Model     MAE      RMSE  MAPE_pct  R_squared  \
# 0  Life Expectancy    Naive  0.5428    1.4984    0.9950     0.9797
# 1  Life Expectancy     Holt  0.5449    1.7460    1.0385     0.9725
# 2  Life Expectancy  AutoReg  9.0079  461.0532   21.9902 -1918.1162
#
#    n_predictions  n_countries_modeled
# 0          11684                  217
# 1          11684                  217
# 2          11684                  217
# Best Life Expectancy model
# <style type="text/css">
# </style>
# <table id="T_13758">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13758_level0_col0" class="col_heading level0 col0" >Dataset</th>
#       <th id="T_13758_level0_col1" class="col_heading level0 col1" >Model</th>
#       <th id="T_13758_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_13758_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_13758_level0_col4" class="col_heading level0 col4" >MAPE_pct</th>
#       <th id="T_13758_level0_col5" class="col_heading level0 col5" >R_squared</th>
#       <th id="T_13758_level0_col6" class="col_heading level0 col6" >n_predictions</th>
#       <th id="T_13758_level0_col7" class="col_heading level0 col7" >n_countries_modeled</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13758_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_13758_row0_col0" class="data row0 col0" >Life Expectancy</td>
#       <td id="T_13758_row0_col1" class="data row0 col1" >Naive</td>
#       <td id="T_13758_row0_col2" class="data row0 col2" >0.5428</td>
#       <td id="T_13758_row0_col3" class="data row0 col3" >1.4984</td>
#       <td id="T_13758_row0_col4" class="data row0 col4" >0.9950</td>
#       <td id="T_13758_row0_col5" class="data row0 col5" >0.9797</td>
#       <td id="T_13758_row0_col6" class="data row0 col6" >11684</td>
#       <td id="T_13758_row0_col7" class="data row0 col7" >217</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_life_model_name = best_life_model["Model"].iloc[0]

best_life_predictions = life_predictions[
    life_predictions["Model"] == best_life_model_name
].copy()

sample_countries = (
    best_life_predictions.groupby(["country_code", "country_name"])["actual"]
    .mean()
    .sort_values(ascending=False)
    .head(3)
    .reset_index()
)

for _, row in sample_countries.iterrows():
    code = row["country_code"]
    name = row["country_name"]

    temp = best_life_predictions[
        best_life_predictions["country_code"] == code
    ].sort_values("year")

    plt.figure(figsize=(10, 5))
    plt.plot(temp["year"], temp["actual"], marker="o", linewidth=2.5, label="Actual Life Expectancy")
    plt.plot(temp["year"], temp["predicted"], marker="o", linewidth=2.5, label=f"Predicted Life Expectancy ({best_life_model_name})")

    plt.title(f"Life Expectancy - Best Model Forecast vs Actual ({name})", fontsize=13, fontweight="bold")
    plt.xlabel("Year")
    plt.ylabel("Life Expectancy (years)")
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
final_life_prediction_table = best_life_predictions[[
    "country_name",
    "country_code",
    "wb_region",
    "year",
    "actual",
    "predicted"
]].copy()

display(format_life_output(final_life_prediction_table.head(15)))
# Out:
# <style type="text/css">
# </style>
# <table id="T_a4663">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a4663_level0_col0" class="col_heading level0 col0" >country_name</th>
#       <th id="T_a4663_level0_col1" class="col_heading level0 col1" >country_code</th>
#       <th id="T_a4663_level0_col2" class="col_heading level0 col2" >wb_region</th>
#       <th id="T_a4663_level0_col3" class="col_heading level0 col3" >year</th>
#       <th id="T_a4663_level0_col4" class="col_heading level0 col4" >actual</th>
#       <th id="T_a4663_level0_col5" class="col_heading level0 col5" >predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4663_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a4663_row0_col0" class="data row0 col0" >Aruba</td>
#       <td id="T_a4663_row0_col1" class="data row0 col1" >ABW</td>
#       <td id="T_a4663_row0_col2" class="data row0 col2" >Latin America & Caribbean </td>
#       <td id="T_a4663_row0_col3" class="data row0 col3" >1970</td>
#       <td id="T_a4663_row0_col4" class="data row0 col4" >67.44</td>
#       <td id="T_a4663_row0_col5" class="data row0 col5" >67.10</td>
#     </tr>
#     <tr>
#       <th id="T_a4663_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_a4663_row1_col0" class="data row1 col0" >Aruba</td>
#       <td id="T_a4663_row1_col1" class="data row1 col1" >ABW</td>
#       <td id="T_a4663_row1_col2" class="data row1 col2" >Latin America & Caribbean </td>
#       <td id="T_a4663_row1_col3" class="data row1 col3" >1971</td>
#       <td id="T_a4663_row1_col4" class="data row1 col4" >67.78</td>
#       <td id="T_a4663_row1_col5" class="data row1 col5" >67.44</td>
#     </tr>
#     <tr>
#       <th id="T_a4663_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_a4663_row2_col0" class="data row2 col0" >Aruba</td>
#       <td id="T_a4663_row2_col1" class="data row2 col1" >ABW</td>
#       <td id="T_a4663_row2_col2" class="data row2 col2" >Latin America & Caribbean </td>
#       <td id="T_a4663_row2_col3" class="data row2 col3" >1972</td>
#       <td id="T_a4663_row2_col4" class="data row2 col4" >68.33</td>
#       <td id="T_a4663_row2_col5" class="data row2 col5" >67.78</td>
#     </tr>
#     <tr>
#       <th id="T_a4663_level0_row3" class="row_heading level0 row3" >9</th>
#       <td id="T_a4663_row3_col0" class="data row3 col0" >Aruba</td>
#       <td id="T_a4663_row3_col1" class="data row3 col1" >ABW</td>
#       <td id="T_a4663_row3_col2" class="data row3 col2" >Latin America & Caribbean </td>
#       <td id="T_a4663_row3_col3" class="data row3 col3" >1973</td>
#       <td id="T_a4663_row3_col4" class="data row3 col4" >68.86</td>
#       <td id="T_a4663_row3_col5" class="data row3 col5" >68.33</td>
#     </tr>
#     <tr>
#       <th id="T_a4663_level0_row4" class="row_heading level0 row4" >12</th>
#       <td id="T_a4663_row4_col0" class="data row4 col0" >Aruba</td>
#       <td id="T_a4663_row4_col1" class="data row4 col1" >ABW</td>
#       <td id="T_a4663_row4_col2" class="data row4 col2" >Latin America & Caribbean </td>
#       <td id="T_a4663_row4_col3" class="data row4 col3" >1974</td>
#       <td id="T_a4663_row4_col4" class="data row4 col4" >69.28</td>
#       <td id="T_a4663_row4_col5" class="data row4 col5" >68.86</td>
#     </tr>
#     <tr>
#       <th id="T_a4663_level0_row5" class="row_heading level0 row5" >15</th>
#       <td id="T_a4663_row5_col0" class="data row5 col0" >Aruba</td>
#       <td id="T_a4663_row5_col1" class="data row5 col1" >ABW</td>
#       <td id="T_a4663_row5_col2" class="data row5 col2" >Latin America & Caribbean </td>
#       <td id="T_a4663_row5_col3" class="data row5 col3" >1975</td>
#       <td id="T_a4663_row5_col4" class="data row5 col4" >69.56</td>
#       <td id="T_a4663_row5_col5" class="data row5 col5" >69.28</td>
#     </tr>
#     <tr>
#       <th id="T_a4663_level0_row6" class="row_heading level0 row6" >18</th>
#       <td id="T_a4663_row6_col0" class="data row6 col0" >Aruba</td>
#       <td id="T_a4663_row6_col1" class="data row6 col1" >ABW</td>
#       <td id="T_a4663_row6_col2" class="data row6 col2" >Latin America & Caribbean </td>
#       <td id="T_a4663_row6_col3" class="data row6 col3" >1976</td>
#       <td id="T_a4663_row6_col4" class="data row6 col4" >69.81</td>
#       <td id="T_a4663_row6_col5" class="data row6 col5" >69.56</td>
#     </tr>
#     <tr>
#       <th id="T_a4663_level0_row7" class="row_heading level0 row7" >21</th>
#       <td id="T_a4663_row7_col0" class="data row7 col0" >Aruba</td>
#       <td id="T_a4663_row7_col1" class="data row7 col1" >ABW</td>
#       <td id="T_a4663_row7_col2" class="data row7 col2" >Latin America & Caribbean </td>
#       <td id="T_a4663_row7_col3" class="data row7 col3" >1977</td>
#       <td id="T_a4663_row7_col4" class="data row7 col4" >70.05</td>
#       <td id="T_a4663_row7_col5" class="data row7 col5" >69.81</td>
#     </tr>
#     <tr>
#       <th id="T_a4663_level0_row8" class="row_heading level0 row8" >24</th>
#       <td id="T_a4663_row8_col0" class="data row8 col0" >Aruba</td>
#       <td id="T_a4663_row8_col1" class="data row8 col1" >ABW</td>
#       <td id="T_a4663_row8_col2" class="data row8 col2" >Latin America & Caribbean </td>
#       <td id="T_a4663_row8_col3" class="data row8 col3" >1978</td>
#       <td id="T_a4663_row8_col4" class="data row8 col4" >70.27</td>
#       <td id="T_a4663_row8_col5" class="data row8 col5" >70.05</td>
#     </tr>
#     <tr>
#       <th id="T_a4663_level0_row9" class="row_heading level0 row9" >27</th>
#       <td id="T_a4663_row9_col0" class="data row9 col0" >Aruba</td>
#       <td id="T_a4663_row9_col1" class="data row9 col1" >ABW</td>
#       <td id="T_a4663_row9_col2" class="data row9 col2" >Latin America & Caribbean </td>
#       <td id="T_a4663_row9_col3" class="data row9 col3" >1979</td>
#       <td id="T_a4663_row9_col4" class="data row9 col4" >70.51</td>
#       <td id="T_a4663_row9_col5" class="data row9 col5" >70.27</td>
#     </tr>
#     <tr>
#       <th id="T_a4663_level0_row10" class="row_heading level0 row10" >30</th>
#       <td id="T_a4663_row10_col0" class="data row10 col0" >Aruba</td>
#       <td id="T_a4663_row10_col1" class="data row10 col1" >ABW</td>
#       <td id="T_a4663_row10_col2" class="data row10 col2" >Latin America & Caribbean </td>
#       <td id="T_a4663_row10_col3" class="data row10 col3" >1980</td>
#       <td id="T_a4663_row10_col4" class="data row10 col4" >70.77</td>
#       <td id="T_a4663_row10_col5" class="data row10 col5" >70.51</td>
#     </tr>
#     <tr>
#       <th id="T_a4663_level0_row11" class="row_heading level0 row11" >33</th>
#       <td id="T_a4663_row11_col0" class="data row11 col0" >Aruba</td>
#       <td id="T_a4663_row11_col1" class="data row11 col1" >ABW</td>
#       <td id="T_a4663_row11_col2" class="data row11 col2" >Latin America & Caribbean </td>
#       <td id="T_a4663_row11_col3" class="data row11 col3" >1981</td>
#       <td id="T_a4663_row11_col4" class="data row11 col4" >71.34</td>
#       <td id="T_a4663_row11_col5" class="data row11 col5" >70.77</td>
#     </tr>
#     <tr>
#       <th id="T_a4663_level0_row12" class="row_heading level0 row12" >36</th>
#       <td id="T_a4663_row12_col0" class="data row12 col0" >Aruba</td>
#       <td id="T_a4663_row12_col1" class="data row12 col1" >ABW</td>
#       <td id="T_a4663_row12_col2" class="data row12 col2" >Latin America & Caribbean </td>
#       <td id="T_a4663_row12_col3" class="data row12 col3" >1982</td>
#       <td id="T_a4663_row12_col4" class="data row12 col4" >71.48</td>
#       <td id="T_a4663_row12_col5" class="data row12 col5" >71.34</td>
#     </tr>
#     <tr>
#       <th id="T_a4663_level0_row13" class="row_heading level0 row13" >39</th>
#       <td id="T_a4663_row13_col0" class="data row13 col0" >Aruba</td>
#       <td id="T_a4663_row13_col1" class="data row13 col1" >ABW</td>
#       <td id="T_a4663_row13_col2" class="data row13 col2" >Latin America & Caribbean </td>
#       <td id="T_a4663_row13_col3" class="data row13 col3" >1983</td>
#       <td id="T_a4663_row13_col4" class="data row13 col4" >71.61</td>
#       <td id="T_a4663_row13_col5" class="data row13 col5" >71.48</td>
#     </tr>
#     <tr>

# %%
SAVE_LIFE_SUMMARY_PATH = "/Users/tonytony/Final Project/Data/Cleaned/life_time_series_model_selection_summary_10y.csv"
SAVE_LIFE_PREDICTIONS_PATH = "/Users/tonytony/Final Project/Data/Cleaned/life_time_series_model_selection_predictions_10y.csv"
SAVE_LIFE_BEST_MODEL_PATH = "/Users/tonytony/Final Project/Data/Cleaned/life_time_series_best_model_10y.csv"

life_summary_sorted.to_csv(SAVE_LIFE_SUMMARY_PATH, index=False)
final_life_prediction_table.to_csv(SAVE_LIFE_PREDICTIONS_PATH, index=False)
best_life_model.to_csv(SAVE_LIFE_BEST_MODEL_PATH, index=False)

print("Saved summary to:")
print(SAVE_LIFE_SUMMARY_PATH)

print("\nSaved best-model predictions to:")
print(SAVE_LIFE_PREDICTIONS_PATH)

print("\nSaved best-model row to:")
print(SAVE_LIFE_BEST_MODEL_PATH)
# Out:
# Saved summary to:
# /Users/tonytony/Final Project/Data/Cleaned/life_time_series_model_selection_summary_10y.csv
#
# Saved best-model predictions to:
# /Users/tonytony/Final Project/Data/Cleaned/life_time_series_model_selection_predictions_10y.csv
#
# Saved best-model row to:
# /Users/tonytony/Final Project/Data/Cleaned/life_time_series_best_model_10y.csv

# %%
COUNTRY_CODE_INPUT = "VNM"
TARGET_YEAR_INPUT = 2030

BEST_BACKTEST_MODEL = best_life_model_name
FUTURE_PROJECTION_MODEL = "Holt"

print("Country code:", COUNTRY_CODE_INPUT)
print("Target year:", TARGET_YEAR_INPUT)
print("Best one-step backtest model:", BEST_BACKTEST_MODEL)
print("Future projection model:", FUTURE_PROJECTION_MODEL)
print("Reason: Holt is used for long-run life expectancy projection because it preserves trend, while Naive can become flat in recursive future forecasts.")
# Out:
# Country code: VNM
# Target year: 2030
# Selected best model: Naive

# %%
def forecast_life_to_target_year(
    long_df,
    country_code,
    target_year,
    model_name,
    value_col="life_expectancy_years",
    window_size=10
):
    country_df = (
        long_df[long_df["country_code"] == country_code][
            ["country_name", "country_code", "wb_region", "year", value_col]
        ]
        .dropna()
        .sort_values("year")
        .copy()
    )

    if country_df.empty:
        raise ValueError(f"Country code {country_code} not found")

    country_name = country_df["country_name"].iloc[0]
    wb_region = country_df["wb_region"].iloc[0]

    year_value_map = dict(zip(country_df["year"].astype(int), country_df[value_col].astype(float)))
    available_years = sorted(year_value_map.keys())
    last_actual_year = max(available_years)

    if len(available_years) < window_size:
        raise ValueError(f"Not enough data for {country_code}. Need at least {window_size} observations.")

    forecast_rows = []

    if target_year <= last_actual_year:
        needed_years = list(range(target_year - window_size, target_year))
        missing_years = [y for y in needed_years if y not in year_value_map]

        if missing_years:
            raise ValueError(f"Missing historical years for direct forecast: {missing_years}")

        train_window = [year_value_map[y] for y in needed_years]
        predicted_value = one_step_life_forecast(
            window_values=train_window,
            model_name=model_name
        )

        actual_value = year_value_map.get(target_year, np.nan)

        result_df = pd.DataFrame([{
            "country_name": country_name,
            "country_code": country_code,
            "wb_region": wb_region,
            "target_year": target_year,
            "window_start_year": needed_years[0],
            "window_end_year": needed_years[-1],
            "model_used": model_name,
            "predicted_life_expectancy": round(predicted_value, 2),
            "actual_life_expectancy": round(actual_value, 2) if pd.notna(actual_value) else np.nan,
            "forecast_type": "direct_from_historical_window"
        }])

        return result_df

    history_map = year_value_map.copy()

    for year_to_predict in range(last_actual_year + 1, target_year + 1):
        available_hist_years = sorted(history_map.keys())

        if len(available_hist_years) < window_size:
            raise ValueError("Not enough historical values to continue recursive forecast")

        window_years = available_hist_years[-window_size:]
        train_window = [history_map[y] for y in window_years]

        predicted_value = one_step_life_forecast(
            window_values=train_window,
            model_name=model_name
        )

        history_map[year_to_predict] = float(predicted_value)

        forecast_rows.append({
            "country_name": country_name,
            "country_code": country_code,
            "wb_region": wb_region,
            "target_year": year_to_predict,
            "window_start_year": window_years[0],
            "window_end_year": window_years[-1],
            "model_used": model_name,
            "predicted_life_expectancy": round(predicted_value, 2),
            "actual_life_expectancy": np.nan,
            "forecast_type": "recursive_future_forecast"
        })

    result_df = pd.DataFrame(forecast_rows)
    return result_df

# %%
target_life_forecast_df = forecast_life_to_target_year(
    long_df=life_long,
    country_code=COUNTRY_CODE_INPUT,
    target_year=TARGET_YEAR_INPUT,
    model_name=FUTURE_PROJECTION_MODEL,
    value_col="life_expectancy_years",
    window_size=WINDOW_SIZE
)

display(format_life_output(target_life_forecast_df))
# Out:
# <style type="text/css">
# </style>
# <table id="T_41a65">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41a65_level0_col0" class="col_heading level0 col0" >country_name</th>
#       <th id="T_41a65_level0_col1" class="col_heading level0 col1" >country_code</th>
#       <th id="T_41a65_level0_col2" class="col_heading level0 col2" >wb_region</th>
#       <th id="T_41a65_level0_col3" class="col_heading level0 col3" >target_year</th>
#       <th id="T_41a65_level0_col4" class="col_heading level0 col4" >window_start_year</th>
#       <th id="T_41a65_level0_col5" class="col_heading level0 col5" >window_end_year</th>
#       <th id="T_41a65_level0_col6" class="col_heading level0 col6" >model_used</th>
#       <th id="T_41a65_level0_col7" class="col_heading level0 col7" >predicted_life_expectancy</th>
#       <th id="T_41a65_level0_col8" class="col_heading level0 col8" >actual_life_expectancy</th>
#       <th id="T_41a65_level0_col9" class="col_heading level0 col9" >forecast_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41a65_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_41a65_row0_col0" class="data row0 col0" >Viet Nam</td>
#       <td id="T_41a65_row0_col1" class="data row0 col1" >VNM</td>
#       <td id="T_41a65_row0_col2" class="data row0 col2" >East Asia & Pacific</td>
#       <td id="T_41a65_row0_col3" class="data row0 col3" >2024</td>
#       <td id="T_41a65_row0_col4" class="data row0 col4" >2014</td>
#       <td id="T_41a65_row0_col5" class="data row0 col5" >2023</td>
#       <td id="T_41a65_row0_col6" class="data row0 col6" >Holt</td>
#       <td id="T_41a65_row0_col7" class="data row0 col7" >74.78</td>
#       <td id="T_41a65_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_41a65_row0_col9" class="data row0 col9" >recursive_future_forecast</td>
#     </tr>
#     <tr>
#       <th id="T_41a65_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_41a65_row1_col0" class="data row1 col0" >Viet Nam</td>
#       <td id="T_41a65_row1_col1" class="data row1 col1" >VNM</td>
#       <td id="T_41a65_row1_col2" class="data row1 col2" >East Asia & Pacific</td>
#       <td id="T_41a65_row1_col3" class="data row1 col3" >2025</td>
#       <td id="T_41a65_row1_col4" class="data row1 col4" >2015</td>
#       <td id="T_41a65_row1_col5" class="data row1 col5" >2024</td>
#       <td id="T_41a65_row1_col6" class="data row1 col6" >Holt</td>
#       <td id="T_41a65_row1_col7" class="data row1 col7" >74.88</td>
#       <td id="T_41a65_row1_col8" class="data row1 col8" >nan</td>
#       <td id="T_41a65_row1_col9" class="data row1 col9" >recursive_future_forecast</td>
#     </tr>
#     <tr>
#       <th id="T_41a65_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_41a65_row2_col0" class="data row2 col0" >Viet Nam</td>
#       <td id="T_41a65_row2_col1" class="data row2 col1" >VNM</td>
#       <td id="T_41a65_row2_col2" class="data row2 col2" >East Asia & Pacific</td>
#       <td id="T_41a65_row2_col3" class="data row2 col3" >2026</td>
#       <td id="T_41a65_row2_col4" class="data row2 col4" >2016</td>
#       <td id="T_41a65_row2_col5" class="data row2 col5" >2025</td>
#       <td id="T_41a65_row2_col6" class="data row2 col6" >Holt</td>
#       <td id="T_41a65_row2_col7" class="data row2 col7" >74.97</td>
#       <td id="T_41a65_row2_col8" class="data row2 col8" >nan</td>
#       <td id="T_41a65_row2_col9" class="data row2 col9" >recursive_future_forecast</td>
#     </tr>
#     <tr>
#       <th id="T_41a65_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_41a65_row3_col0" class="data row3 col0" >Viet Nam</td>
#       <td id="T_41a65_row3_col1" class="data row3 col1" >VNM</td>
#       <td id="T_41a65_row3_col2" class="data row3 col2" >East Asia & Pacific</td>
#       <td id="T_41a65_row3_col3" class="data row3 col3" >2027</td>
#       <td id="T_41a65_row3_col4" class="data row3 col4" >2017</td>
#       <td id="T_41a65_row3_col5" class="data row3 col5" >2026</td>
#       <td id="T_41a65_row3_col6" class="data row3 col6" >Holt</td>
#       <td id="T_41a65_row3_col7" class="data row3 col7" >75.05</td>
#       <td id="T_41a65_row3_col8" class="data row3 col8" >nan</td>
#       <td id="T_41a65_row3_col9" class="data row3 col9" >recursive_future_forecast</td>
#     </tr>
#     <tr>
#       <th id="T_41a65_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_41a65_row4_col0" class="data row4 col0" >Viet Nam</td>
#       <td id="T_41a65_row4_col1" class="data row4 col1" >VNM</td>
#       <td id="T_41a65_row4_col2" class="data row4 col2" >East Asia & Pacific</td>
#       <td id="T_41a65_row4_col3" class="data row4 col3" >2028</td>
#       <td id="T_41a65_row4_col4" class="data row4 col4" >2018</td>
#       <td id="T_41a65_row4_col5" class="data row4 col5" >2027</td>
#       <td id="T_41a65_row4_col6" class="data row4 col6" >Holt</td>
#       <td id="T_41a65_row4_col7" class="data row4 col7" >75.11</td>
#       <td id="T_41a65_row4_col8" class="data row4 col8" >nan</td>
#       <td id="T_41a65_row4_col9" class="data row4 col9" >recursive_future_forecast</td>
#     </tr>
#     <tr>
#       <th id="T_41a65_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_41a65_row5_col0" class="data row5 col0" >Viet Nam</td>
#       <td id="T_41a65_row5_col1" class="data row5 col1" >VNM</td>
#       <td id="T_41a65_row5_col2" class="data row5 col2" >East Asia & Pacific</td>
#       <td id="T_41a65_row5_col3" class="data row5 col3" >2029</td>
#       <td id="T_41a65_row5_col4" class="data row5 col4" >2019</td>
#       <td id="T_41a65_row5_col5" class="data row5 col5" >2028</td>
#       <td id="T_41a65_row5_col6" class="data row5 col6" >Holt</td>
#       <td id="T_41a65_row5_col7" class="data row5 col7" >75.14</td>
#       <td id="T_41a65_row5_col8" class="data row5 col8" >nan</td>
#       <td id="T_41a65_row5_col9" class="data row5 col9" >recursive_future_forecast</td>
#     </tr>
#     <tr>
#       <th id="T_41a65_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_41a65_row6_col0" class="data row6 col0" >Viet Nam</td>
#       <td id="T_41a65_row6_col1" class="data row6 col1" >VNM</td>
#       <td id="T_41a65_row6_col2" class="data row6 col2" >East Asia & Pacific</td>
#       <td id="T_41a65_row6_col3" class="data row6 col3" >2030</td>
#       <td id="T_41a65_row6_col4" class="data row6 col4" >2020</td>
#       <td id="T_41a65_row6_col5" class="data row6 col5" >2029</td>
#       <td id="T_41a65_row6_col6" class="data row6 col6" >Holt</td>
#       <td id="T_41a65_row6_col7" class="data row6 col7" >75.14</td>
#       <td id="T_41a65_row6_col8" class="data row6 col8" >nan</td>
#       <td id="T_41a65_row6_col9" class="data row6 col9" >recursive_future_forecast</td>
#     </tr>
#   </tbody>
# </table>
